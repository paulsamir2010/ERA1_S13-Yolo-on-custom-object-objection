# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15921, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 15921 (delta 17), reused 28 (delta 13), pack-reused 15880
# Receiving objects: 100% (15921/15921), 14.66 MiB | 12.15 MiB/s, done.
# Resolving deltas: 100% (10916/10916), done.

# %%
# %pwd
# Out:
# '/content'

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.6/609.6 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.7 MB/s eta 0:00:00
# ...

# %%
#!unzip ‘/content/drive/MyDrive/spoonnknife.zip’
# !unzip /content/drive/MyDrive/spoonnknife.zip
# Out:
# Archive:  /content/drive/MyDrive/spoonnknife.zip
#    creating: spoonnknife/images/
#    creating: spoonnknife/images/train/
#   inflating: spoonnknife/images/train/IMG_20230812_105300.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105304.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105312.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105315.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105320.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105323.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105330.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105335.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105351.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105354.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105400.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105407.jpg
#   inflating: spoonnknife/images/train/IMG_20230812_105417.jpg
# ...

# %%
#!python train.py –-imgsz 640 –-batch-size 8 –-epochs 2 –-data /content/yolov5/data/customPath.yaml –-weights yolov5s.pt
#!python train.py –-batch-size 8 –-epochs 2 –-data /content/yolov5/data/customPath.yaml #–-weights yolov5s.pt
# Out:
# usage: train.py
#        [-h]
#        [--weights WEIGHTS]
#        [--cfg CFG]
#        [--data DATA]
#        [--hyp HYP]
#        [--epochs EPOCHS]
#        [--batch-size BATCH_SIZE]
#        [--imgsz IMGSZ]
#        [--rect]
#        [--resume [RESUME]]
#        [--nosave]
#        [--noval]
#        [--noautoanchor]
#        [--noplots]
#        [--evolve [EVOLVE]]
#        [--bucket BUCKET]
#        [--cache [CACHE]]
#        [--image-weights]
#        [--device DEVICE]
#        [--multi-scale]
#        [--single-cls]
#        [--optimizer {SGD,Adam,AdamW}]
#        [--sync-bn]
#        [--workers WORKERS]
#        [--project PROJECT]
#        [--name NAME]
#        [--exist-ok]
#        [--quad]
#        [--cos-lr]
#        [--label-smoothing LABEL_SMOOTHING]
#        [--patience PATIENCE]
#        [--freeze FREEZE [FREEZE ...]]
#        [--save-period SAVE_PERIOD]
#        [--seed SEED]
#        [--local_rank LOCAL_RANK]
#        [--entity ENTITY]
# ...

# %%
  #epochs=100, batch_size=16, imgsz=640  epochs=100, batch_size=16, imgsz=640  data=data/coco128.yaml  weights=yolov5s.pt

# %%
# !python train.py --epochs 50 --imgsz 640 --data /content/yolov5/data/customPath.yaml --weights yolov5s.pt --batch-size 16
#!python train.py
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/customPath.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# ...

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_105300.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_105300.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_105300.jpg: 640x288 1 spoon, 45.9ms
# Speed: 0.6ms pre-process, 45.9ms inference, 3.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_105330.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_105330.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_105330.jpg: 288x640 1 spoon, 68.4ms
# Speed: 0.7ms pre-process, 68.4ms inference, 2.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_105427.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_105427.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_105427.jpg: 288x640 1 spoon, 41.4ms
# Speed: 0.5ms pre-process, 41.4ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_105955.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_105955.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_105955.jpg: 288x640 1 spoon, 42.2ms
# Speed: 0.5ms pre-process, 42.2ms inference, 2.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_111346.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_111346.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_111346.jpg: 288x640 1 knife, 43.7ms
# Speed: 0.6ms pre-process, 43.7ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_111605.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_111605.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_111605.jpg: 640x288 1 knife, 46.6ms
# Speed: 0.6ms pre-process, 46.6ms inference, 2.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_115713.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_115713.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_115713.jpg: 640x288 1 knife, 1 spoon, 47.3ms
# Speed: 0.5ms pre-process, 47.3ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/train/IMG_20230812_115754.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/train/IMG_20230812_115754.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/train/IMG_20230812_115754.jpg: 640x288 1 knife, 1 spoon, 67.7ms
# Speed: 0.6ms pre-process, 67.7ms inference, 2.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
# validation data
# !python detect.py --weights '/content/yolov5/runs/train/exp7/weights/best.pt' --source '/content/yolov5/spoonnknife/images/val/IMG_20230812_115757.jpg'
# Out:
# detect: weights=['/content/yolov5/runs/train/exp7/weights/best.pt'], source=/content/yolov5/spoonnknife/images/val/IMG_20230812_115757.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/spoonnknife/images/val/IMG_20230812_115757.jpg: 640x288 1 knife, 1 spoon, 44.7ms
# Speed: 0.5ms pre-process, 44.7ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp10
